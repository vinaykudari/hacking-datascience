# %%
import matplotlib.pyplot as plt
import matplotlib_venn as venn
A = {5,8,4,6}
B = {2,3,4,5,6,7}
C = {2,4,6}
D = {2,3,4,7}
venn.venn3([A,B,D])
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib_venn\_venn3.py:117: UserWarning: Bad circle positioning
#   warnings.warn("Bad circle positioning")
